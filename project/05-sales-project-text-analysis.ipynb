# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/items-ff-final4/Items_ff_final4.csv
# /kaggle/input/text-analysis/save.p
# /kaggle/input/items-ff3/Items_ff_final3.csv

# %%
Items = pd.read_csv("../input/items-ff-final4/Items_ff_final4.csv")
Items.head()
#Items.shape[0]
# Out:
#   creation_time  location  condition  \
# 0    2019-04-03         1          0
# 1    2019-04-03         1          0
# 2    2019-04-03         1          0
# 3    2019-04-03         1          0
# 4    2020-02-15         0          0
#
#                                          description  image_cnt  returns_cnt  \
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...  -0.928999    -0.200147
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...  -0.928999    -0.200147
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...  -0.928999    -0.200147
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...  -0.928999    -0.200147
# 4  The pocket watch features clear Roman numerals...   0.442432    -0.200147
#
#    star_rating  revised_star_rating  sales_cyber_monday  sales_black_friday  \
# 0            4                    5                   0                   0
# 1            4                    5                   0                   0
# 2            4                    5                   0                   0
# 3            4                    5                   0                   0
# 4            2                    5                   0                   0
#
#    ...  ebay_price_log  competitor_price_log  amazon_price_log  profit_log  \
# 0  ...       -0.705731             -0.218419         -0.515346   -0.620118
# 1  ...       -0.652616             -0.218419         -0.564058   -0.530243
# 2  ...       -0.596803             -0.218419         -0.564058   -0.476129
# 3  ...        0.168694             -0.218419          0.232270   -0.328885
# 4  ...       -0.970477             -0.765717         -0.769951   -0.581604
#
#    price_diff_competitor_log  profit_pct_sqrt  total_sales   season1  \
# 0                          2                2     2.208650 -0.670265
# 1                          2                2     2.208650 -0.670265
# 2                          2                2     2.208650 -0.670265
# 3                          5                2     2.208650 -0.670265
# 4                          3                2    -0.370716 -0.670265
#
#     season2   season3
# 0 -0.582267  2.111037
# 1 -0.582267  2.111037
# 2 -0.582267  2.111037
# 3 -0.582267  2.111037
# 4  1.717423 -0.473700
#
# [5 rows x 34 columns]

# %%
#Items.rename(columns={'Items1$total_sales': 'total_sales'}, inplace=True)
#Items.drop(columns=['description'], inplace=True)
Items['location'] = Items['location'].astype('category')
Items['condition'] = Items['condition'].astype('category')
Items['star_rating'] = Items['star_rating'].astype('category')
Items['revised_star_rating'] = Items['revised_star_rating'].astype('category')
Items['sales_cyber_monday'] = Items['sales_cyber_monday'].astype('category')
Items['sales_black_friday'] = Items['sales_black_friday'].astype('category')
Items['sales_colombus_day'] = Items['sales_colombus_day'].astype('category')
Items['sales_labor_day'] = Items['sales_labor_day'].astype('category')
Items['sales_presidents_day'] = Items['sales_presidents_day'].astype('category')
Items['sales_4th_july'] = Items['sales_4th_july'].astype('category')
Items['sales_newyear'] = Items['sales_newyear'].astype('category')
Items['sales_xms'] = Items['sales_xms'].astype('category')
Items['success'] = Items['success'].astype('category')
Items['category_size_rank'] = Items['category_size_rank'].astype('category')
Items['brand_size'] = Items['brand_size'].astype('category')
Items['popular_brand'] = Items['popular_brand'].astype('category')
Items['category_size_rank'] = Items['category_size_rank'].astype('category')
Items['review_count_log'] = Items['review_count_log'].astype('category')
Items['price_diff_competitor_log'] = Items['price_diff_competitor_log'].astype('category')
Items['profit_pct_sqrt'] = Items['profit_pct_sqrt'].astype('category')
Items['reviews_cnt_category'] = Items['reviews_cnt_category'].astype('category')
Items['creation_time'] = Items['creation_time'].astype('datetime64')
Items.columns
# Out:
# Index(['creation_time', 'location', 'condition', 'description', 'image_cnt',
#        'returns_cnt', 'star_rating', 'revised_star_rating',
#        'sales_cyber_monday', 'sales_black_friday', 'sales_colombus_day',
#        'sales_labor_day', 'sales_presidents_day', 'sales_4th_july',
#        'sales_newyear', 'sales_xms', 'success', 'item_rating_rank_by_category',
#        'category_size_rank', 'brand_size', 'reviews_cnt_category',
#        'popular_brand', 'description_word_cnt_log', 'review_count_log',
#        'ebay_price_log', 'competitor_price_log', 'amazon_price_log',
#        'profit_log', 'price_diff_competitor_log', 'profit_pct_sqrt',
#        'total_sales', 'season1', 'season2', 'season3'],
#       dtype='object')

# %%
#!pip install nltk
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
text = Items['description'].astype('str')
#text = text.sum()

# %%
text_df = pd.DataFrame()
text_df['description'] = text
text_df.head
text_df['char_count'] = text_df['description'].str.len() ## this also includes spaces
text_df[['description','char_count']].head()
# Out:
#                                          description  char_count
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...         178
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...         178
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...         178
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...         178
# 4  The pocket watch features clear Roman numerals...         532

# %%
# Average word length
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

text_df['avg_word'] = text_df['description'].apply(lambda x: avg_word(x))
text_df[['description','avg_word']].head()
# Out:
#                                          description  avg_word
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...  5.629630
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...  5.629630
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...  5.629630
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...  5.629630
# 4  The pocket watch features clear Roman numerals...  4.793478

# %%
# Number of stop words
from nltk.corpus import stopwords
stop = stopwords.words('english')

text_df['stopwords'] = text_df['description'].apply(lambda x: len([x for x in x.split() if x in stop]))
text_df[['description','stopwords']].head()
# Out:
#                                          description  stopwords
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...          1
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...          1
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...          1
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...          1
# 4  The pocket watch features clear Roman numerals...         15

# %%
# Number of numeric characters
text_df['numerics'] = text_df['description'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
text_df[['description','numerics']].head()
# Out:
#                                          description  numerics
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...         0
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...         0
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...         0
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...         0
# 4  The pocket watch features clear Roman numerals...         4

# %%
# Number of UPPER CASE words
text_df['upper'] = text_df['description'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
text_df[['description','upper']].head()
# Out:
#                                          description  upper
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...      5
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...      5
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...      5
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...      5
# 4  The pocket watch features clear Roman numerals...      0

# %% [markdown]
# **Preprocessing**

# %%
# Lower case,remove stop words and Punctuation
from nltk.corpus import stopwords

text_df['text_df'] = text_df['description'].apply(lambda x: " ".join(x.lower() for x in x.split()))
text_df['text_df'] = text_df['text_df'].str.replace('[^\w\s]','')

stop = stopwords.words('english')
text_df['text_df'] = text_df['text_df'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
text_df['description'].head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# 0    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 1    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 2    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 3    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 4    The pocket watch features clear Roman numerals...
# Name: description, dtype: object

# %%
freq = pd.Series(' '.join(text_df['description']).split()).value_counts()[:10]
freq
freq = list(freq.index)
text_df['description'] = text_df['description'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
text_df['description'].head()
# Out:
# 0    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 1    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 2    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 3    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 4    The pocket watch features clear Roman numerals...
# Name: description, dtype: object

# %%
freq_rare = pd.Series(' '.join(text_df['description']).split()).value_counts()[-10:]
freq_rare
freq = list(freq_rare.index)
text_df['description'] = text_df['description'].apply(lambda x: " ".join(x for x in x.split() if x not in freq_rare))
text_df['description'].head()
# Out:
# 0    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 1    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 2    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 3    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 4    The pocket watch features clear Roman numerals...
# Name: description, dtype: object

# %%
from textblob import TextBlob
text_df['description'][:5].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0    Aplstar E26 E27 Right Pocket,8-pack Black Madi...
# 1    Aplstar E26 E27 Right Pocket,8-pack Black Madi...
# 2    Aplstar E26 E27 Right Pocket,8-pack Black Madi...
# 3    Aplstar E26 E27 Right Pocket,8-pack Black Madi...
# 4    The pocket watch features clear Woman numerous...
# Name: description, dtype: object

# %% [markdown]
# **Tokenization**

# %%
from textblob import TextBlob
TextBlob(text_df['description'][1]).words
# Out:
# WordList(['Aplstar', 'E26', 'E27', 'Light', 'Socket,8-pack', 'Black', 'Edison', 'Retro', 'Pendant', 'lamp', 'holder', 'E26', 'E27', 'Plastic', 'Standard', 'Screw-in', 'Socket', 'Maximum', 'Wattage', '250W', 'Heat', 'Resistant', 'Up', '200℃', 'Fire', 'Resistant'])

# %%
from textblob import Word
text_df['description'] = text_df['description'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
text_df['description'].head()
# Out:
# 0    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 1    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 2    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 3    Aplstar E26 E27 Light Socket,8-pack Black Edis...
# 4    The pocket watch feature clear Roman numeral d...
# Name: description, dtype: object

# %% [markdown]
# **Sentiment Analysis**

# %%
text_df['sentiment'] = text_df['description'].apply(lambda x: TextBlob(x).sentiment[0] )
text_df[['description','sentiment']].head(10)
# Out:
#                                          description  sentiment
# 0  Aplstar E26 E27 Light Socket,8-pack Black Edis...   0.077778
# 1  Aplstar E26 E27 Light Socket,8-pack Black Edis...   0.077778
# 2  Aplstar E26 E27 Light Socket,8-pack Black Edis...   0.077778
# 3  Aplstar E26 E27 Light Socket,8-pack Black Edis...   0.077778
# 4  The pocket watch feature clear Roman numeral d...   0.338889
# 5  Plastic molded miter box 35-250 plus 35-200 Ul...  -0.366667
# 6  The Prochef teflon non-stick cake tin ideal wa...   0.305556
# 7  Pet & Wild Animal Control Use biocides safely....   0.300000
# 8  Cellulite, also known a orange peel skin, toda...   0.084352
# 9  The original Stretch Armstrong back! stretch h...   0.248380

# %%
text_df.drop('description',axis=1, inplace = True)
text_df.to_csv("./text_analysis")

# %%
#import pickle
#pickle.dump( text_df, open( "save.p", "wb" ) )
